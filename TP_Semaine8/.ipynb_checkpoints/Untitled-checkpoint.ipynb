# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import misc

# %%
x = np.linspace(0,0.8,100)
y = np.cos(x) - x**3
fig, ax = plt.subplots(1,1,figsize=(10,10))
ax.plot(x, y,label="ma courbe")
ax.set_title(r'$y=\cos(x)-x**3$')
ax.set_xlabel("x")
ax.set_ylabel("np.cos(x) - x**3")
ax.legend()

# %%
x = np.linspace(-1.5,1.5,100)
y =x**2 - 2
fig, ax = plt.subplots(1,1,figsize=(10,10))

# %%
def dichotomie(a,b,eps,f):
    x0 = a
    xpremier = a
    x1 = b
    x2 = 0.5*(x0+x1)
    res = 0
    n = 0
    while  np.abs(f(x2)) >= eps :
        if(f(x0) * f(x2)) <=0:
            x1 = x2
        else:
            x0 = x2
        x2 =  0.5*(x0+x1)
        n+=1
    res = np.abs((x1 - x0)*2**(-n)) - xpremier
    return x2,res

# %%
def f1(x):
    return np.cos(x) - x**3

def f2(x, a):
    return  x**2 - a

dichotomie(0,1,10**-5,coss)
# Out:
# (0.8654708862304688, 2.3283064365386963e-10)

# %%
x = 0.8654708862304688
print(np.cos(x) - x**3)
# Out:
# 9.467454266331998e-06

# %%
def newton1(x0,f , fprime, Nmax, eps):
    n=0
    while np.abs(f(x0))>= eps & n<Nmax:
        x0 -= f(x0)/fprime(x0)
        n+=1
    return x0

# %%
def f1Prime(x):
    return np.cos(x) - x**3

def f2Prime(x, a):
    return  x**2 - a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-d1ccf0d5cc80> in <module>
# ----> 1 misc.derivative(f1(x))
#
# TypeError: derivative() missing 1 required positional argument: 'x0'

# %%
newton1(0,f1 , fprime, Nmax, eps):
